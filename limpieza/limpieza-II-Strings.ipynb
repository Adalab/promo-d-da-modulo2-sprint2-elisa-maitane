# %% [markdown]
# Por lo tanto, en este ejercicio nos queda por limpiar algunas columnas del conjunto de datos, así que manos a la obra. Vamos a ver que podemos hacer para cada una de las columnas y os dejaremos algunas pistas 😉. Para esto trabajaremos con el fichero generado en Limpieza I.

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import os
if 'limpieza' not in os.getcwd():
    os.chdir('limpieza')

# %%
pd.options.display.max_columns = None

# %%
df_bancario = pd.read_csv("../datos/bank-additional-full2.csv", index_col = 0)
df_bancario.head(5)
# Out:
#    age        job  marital    education  default  housing  loan    contact  \
# 0   56  housemaid  married     basic.4y      0.0      0.0   0.0  telephone
# 1   57   services  married  high.school      NaN      0.0   0.0  telephone
# 2   37   services  married  high.school      0.0      1.0   0.0  telephone
# 3   40     admin.  married     basic.6y      0.0      0.0   0.0  telephone
# 4   56   services  married  high.school      0.0      0.0   1.0  telephone
#
#    duration  campaign  pdays  previous     poutcome  emp,var,rate  \
# 0       261         1    999         0  NONEXISTENT           1.1
# 1       149         1    999         0  NONEXISTENT           1.1
# 2       226         1    999         0  NONEXISTENT           1.1
# 3       151         1    999         0  NONEXISTENT           1.1
# 4       307         1    999         0  NONEXISTENT           1.1
#
#    cons,price,idx  cons,conf,idx  euribor3m nr,employed   y  month_day_week
# 0          93.994          -36.4      4.857      5191,0  no  ['may', 'mon']
# 1          93.994          -36.4      4.857      5191,0  no  ['may', 'mon']
# 2          93.994          -36.4      4.857      5191,0  no  ['may', 'mon']
# 3          93.994          -36.4      4.857      5191,0  no  ['may', 'mon']
# 4          93.994          -36.4      4.857      5191,0  no  ['may', 'mon']

# %% [markdown]
# 1. Columnas loan, housing y default: estas columnas contienen valores únicos de 0 y 1. Esto puede parecer poco intuitivo a la hora de la extracción de conclusiones y en las visualizaciones. El objetivo de este ejercicio es que cambies los valores númericos por "Si" y "No". A que corresponde cada uno de los valores lo tenéis en el pair de Limpieza I.

# %%
mapa = {0.0: 'No', 1.0: 'Si'}

# %%
for col in df_bancario.columns[4:7]:
    df_bancario[col] = df_bancario[col].map(mapa, na_action="ignore")

df_bancario.head()
# Out:
#    age        job  marital    education default housing loan    contact  \
# 0   56  housemaid  married     basic.4y      No      No   No  telephone
# 1   57   services  married  high.school     NaN      No   No  telephone
# 2   37   services  married  high.school      No      Si   No  telephone
# 3   40     admin.  married     basic.6y      No      No   No  telephone
# 4   56   services  married  high.school      No      No   Si  telephone
#
#    duration  campaign  pdays  previous     poutcome  emp,var,rate  \
# 0       261         1    999         0  NONEXISTENT           1.1
# 1       149         1    999         0  NONEXISTENT           1.1
# 2       226         1    999         0  NONEXISTENT           1.1
# 3       151         1    999         0  NONEXISTENT           1.1
# 4       307         1    999         0  NONEXISTENT           1.1
#
#    cons,price,idx  cons,conf,idx  euribor3m nr,employed   y  month_day_week
# 0          93.994          -36.4      4.857      5191,0  no  ['may', 'mon']
# 1          93.994          -36.4      4.857      5191,0  no  ['may', 'mon']
# 2          93.994          -36.4      4.857      5191,0  no  ['may', 'mon']
# 3          93.994          -36.4      4.857      5191,0  no  ['may', 'mon']
# 4          93.994          -36.4      4.857      5191,0  no  ['may', 'mon']

# %% [markdown]
# 2. Para la columna de education, si nos fijamos en sus valores únicos veremos que tenemos puntos. El objetivo de este ejercicio es que quitéis los puntos de esos valores y los reemplacéis por espacios.

# %%
df_bancario['education'] = df_bancario['education'].str.replace('.',' ')
df_bancario.head()
# Out:
# /tmp/ipykernel_4687/2193172620.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_bancario['education'] = df_bancario['education'].str.replace('.',' ')
#    age        job  marital    education default housing loan    contact  \
# 0   56  housemaid  married     basic 4y      No      No   No  telephone
# 1   57   services  married  high school     NaN      No   No  telephone
# 2   37   services  married  high school      No      Si   No  telephone
# 3   40     admin.  married     basic 6y      No      No   No  telephone
# 4   56   services  married  high school      No      No   Si  telephone
#
#    duration  campaign  pdays  previous     poutcome  emp,var,rate  \
# 0       261         1    999         0  NONEXISTENT           1.1
# 1       149         1    999         0  NONEXISTENT           1.1
# 2       226         1    999         0  NONEXISTENT           1.1
# 3       151         1    999         0  NONEXISTENT           1.1
# 4       307         1    999         0  NONEXISTENT           1.1
#
#    cons,price,idx  cons,conf,idx  euribor3m nr,employed   y  month_day_week
# 0          93.994          -36.4      4.857      5191,0  no  ['may', 'mon']
# 1          93.994          -36.4      4.857      5191,0  no  ['may', 'mon']
# 2          93.994          -36.4      4.857      5191,0  no  ['may', 'mon']
# 3          93.994          -36.4      4.857      5191,0  no  ['may', 'mon']
# 4          93.994          -36.4      4.857      5191,0  no  ['may', 'mon']

# %% [markdown]
# 3. Para la columna job, hay un valor único que esta abreviado (admin.), cambiad la abreviatura por el nombre completo.

# %%
df_bancario['job'] = df_bancario['job'].str.replace('admin.','administrator')
df_bancario.sample(5)
# Out:
# /tmp/ipykernel_4687/584409843.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_bancario['job'] = df_bancario['job'].str.replace('admin.','administrator')
#        age         job   marital            education default housing loan  \
# 39668   52  management   married    university degree      No      No   No
# 27797   32  management    single    university degree      No      Si   No
# 10039   44  technician   married  professional course      No      No   No
# 26603   31    services    single          high school      No      Si   No
# 21281   53     retired  divorced  professional course      No      No   No
#
#          contact  duration  campaign  pdays  previous     poutcome  \
# 39668   cellular       404         2      9         1      SUCCESS
# 27797   cellular       427         3    999         0  NONEXISTENT
# 10039  telephone       171         1    999         0  NONEXISTENT
# 26603   cellular       452         2    999         0  NONEXISTENT
# 21281   cellular       119         3    999         0  NONEXISTENT
#
#        emp,var,rate  cons,price,idx  cons,conf,idx  euribor3m nr,employed  \
# 39668          -1.8          93.876          -40.0      0.684      5008,7
# 27797          -1.8          92.843          -50.0      1.687      5099,1
# 10039           1.4          94.465          -41.8      4.958      5228,1
# 26603          -0.1          93.200          -42.0      4.076      5195,8
# 21281           1.4          93.444          -36.1      4.963      5228,1
#
#          y  month_day_week
# 39668  yes  ['may', 'fri']
# 27797  yes  ['mar', 'tue']
# 10039   no  ['jun', 'thu']
# 26603   no  ['nov', 'thu']
# 21281   no  ['aug', 'mon']

# %%
df_bancario['job'].unique()

# comprobamos que nos ha cambiado correctamente la palabra
# Out:
# array(['housemaid', 'services', 'administrator', 'blue-collar',
#        'technician', 'retired', 'management', 'unemployed',
#        'self-employed', nan, 'entrepreneur', 'student'], dtype=object)

# %% [markdown]
# 4. La columna month_day_week tiene una lista que contiene información muy diferente. El objetivo de este ejercicio es separar esta columna en dos nuevas, donde tengamos los meses en una columna y los días de la semana en otra.

# %%
eliminar_corchetes = lambda x: x.strip('[]')

# %%
df_bancario['month_day_week'] = df_bancario['month_day_week'].apply(eliminar_corchetes)

# %%
df_bancario[['month','day_week']] = df_bancario['month_day_week'].str.split(',', expand=True)
df_bancario.head()
# Out:
#    age            job  marital    education default housing loan    contact  \
# 0   56      housemaid  married     basic 4y      No      No   No  telephone
# 1   57       services  married  high school     NaN      No   No  telephone
# 2   37       services  married  high school      No      Si   No  telephone
# 3   40  administrator  married     basic 6y      No      No   No  telephone
# 4   56       services  married  high school      No      No   Si  telephone
#
#    duration  campaign  pdays  previous     poutcome  emp,var,rate  \
# 0       261         1    999         0  NONEXISTENT           1.1
# 1       149         1    999         0  NONEXISTENT           1.1
# 2       226         1    999         0  NONEXISTENT           1.1
# 3       151         1    999         0  NONEXISTENT           1.1
# 4       307         1    999         0  NONEXISTENT           1.1
#
#    cons,price,idx  cons,conf,idx  euribor3m nr,employed   y month_day_week  \
# 0          93.994          -36.4      4.857      5191,0  no   'may', 'mon'
# 1          93.994          -36.4      4.857      5191,0  no   'may', 'mon'
# 2          93.994          -36.4      4.857      5191,0  no   'may', 'mon'
# 3          93.994          -36.4      4.857      5191,0  no   'may', 'mon'
# 4          93.994          -36.4      4.857      5191,0  no   'may', 'mon'
#
#    month day_week
# 0  'may'    'mon'
# 1  'may'    'mon'
# 2  'may'    'mon'
# 3  'may'    'mon'
# 4  'may'    'mon'

# %% [markdown]
# 5. Guarda el csv con las columnas limpias para seguir trabajando con este dataframe limpio.

# %%
df_bancario.to_csv("../datos/bank-additional-full3.csv")
